# %% [markdown]
# <a href="https://colab.research.google.com/github/Pedro2318/DataCamp-PROJECTS/blob/main/Entrega_1_PEDRO_BERNARDO_DOS_SANTOS_MELO.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
#
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---
# ***Pedro Bernardo dos Santos Melo***
#
# ### Data Analysis of Airbnb dataset
#
# [Airbnb](https://www.airbnb.com/) is a online marketplace for vacation rentals. It allows people to rent out their homes or apartments to travelers, as an alternative to traditional hotel lodging. It was founded in 2008, and is currently headquartered in San Francisco, California.
#
# Airbnb is a well-known and large company. It has become one of the world's largest providers of short-term lodging, with millions of listings in over 220 countries and territories worldwide. As of 2021, it is valued at over $100 billion and has been publicly traded on the NASDAQ stock exchange since December 2020.
#
# Airbnb offers a program that makes a significant amount of data from some major cities around the world accessible. The data can be obtained through the [Inside Airbnb](http://insideairbnb.com/get-the-data.html), which enables users to download a significant amount of data for use in data science projects and solutions.
#
# <center>
#   <img
#     src="https://raw.githubusercontent.com/Pedro2318/DataCamp-PROJECTS/main/images/image.png"
#     alt="Picture"
#     style="display: block; margin: 0 auto"
#     width="50%"
#      >
#      </center>
#
# **In this project, I will conduct an analysis of the data related to the cities of Barcelona and Madrid on Airbnb.** Specifically, I will be looking at factors such as the number of listings, occupancy rate, and average nightly rate to determine which city would be the most advantageous to invest in rental apartments on the Airbnb platform. I will also consider other metrics such as locations, amenities, and reviews from guests to get a comprehensive understanding of the market. The insights obtained from the data analysis will be used to make an informed decision on where to invest in rental properties on the Airbnb platform.
#
# <center><img alt="Analisando Airbnb" width="10%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>

# %% [markdown]
# ## Which city, Barcelona or Madrid, would be the most profitable location to invest in?
#
# The relationship between the hotel sector and Airbnb in Spain is complex and has been influenced by various factors such as regulation, competition, and market demand. In recent years, the hotel sector has experienced growth and investment, but it has also faced increasing competition from short-term rental platforms like Airbnb. Hotels offer a more traditional and structured accommodation experience, with amenities such as daily housekeeping, 24-hour reception, and on-site dining options. Airbnb, on the other hand, offers a more unique and local experience, allowing travelers to stay in a residential area and potentially live like a local. Ultimately, the choice between a hotel and Airbnb will depend on the individual's priorities, budget, and travel style.
#
#
# #**Madrid**
# <p align="center">
#     <img src="https://raw.githubusercontent.com/Pedro2318/DataCamp-PROJECTS/main/images/04b52cd1-bd74-47f5-a9a2-77ad27c8ae3a.jpeg"
#         width="50%"
#         alt="Picture"
#         style="display: block; margin: 0 auto">
#
# Tourism in Madrid is usually robust and the city is considered one of the most popular tourist destinations in Europe. The main tourist spots in Madrid include the Royal Palace of Madrid, the Prado Museum, the Retiro Park, the Thyssen-Bornemisza Museum, the Santiago Bernabéu Stadium and the Puerta del Sol.
# People visit Madrid for its rich cultural heritage, art, architecture, and gastronomy. The city is also known for its lively nightlife and its numerous shopping and dining options. Additionally, Madrid is a hub for sports fans, with football being the most popular sport in the city, and the Santiago Bernabéu Stadium being one of the most iconic venues for Real Madrid games.
#
#
# #**Barcelona**
# <p align="center">
#     <img src="https://raw.githubusercontent.com/Pedro2318/DataCamp-PROJECTS/main/images/6de2cdb4-2386-40f2-8dfc-73cfe18b4a69.jpeg"
#         width="50%"
#         alt="Picture"
#         style="display: block; margin: 0 auto">
#
# Tourism in Barcelona is one of the main drivers of the city's economy and attracts millions of visitors each year. The main tourist spots in Barcelona include the Sagrada Familia, Park Güell, the Gothic Quarter, the Picasso Museum, and the Joan Miro Foundation.
# People visit Barcelona for its rich cultural heritage, architecture, and artistic heritage, with Antoni Gaudi's works being a major draw. The city is also known for its beaches, such as Barceloneta, and its vibrant food and nightlife scene. Additionally, Barcelona has a rich sporting culture, with football being one of the most popular sports in the city, and the Camp Nou Stadium being one of the largest and most iconic football venues in the world.
# Overall, visitors are drawn to Barcelona for its unique blend of art, culture, and modern amenities, making it a popular destination for both tourists and business travelers.
#
# In 2016, the Barcelona City Council implemented a regulation aimed at controlling the proliferation of short-term rental platforms like Airbnb. This regulation was followed by the Madrid City Council in 2019. The regulation mandates that Airbnb hosts register their properties with the city, pay the appropriate tourist taxes, and comply with various rules regarding noise control, safety, and building usage. The introduction of this regulation was driven by concerns over the rapid growth of short-term rentals and its impact on housing affordability and availability. The purpose of the regulation is to strike a balance between the needs of tourists, hosts, and the local community, while ensuring a safe and enjoyable experience for all.

# %% [markdown]
# ## Data Gathering
# It is the first step in the data analysis process, and the quality and completeness of the data will greatly impact the results of the analysis.
#
# In this case, all data used here was obtained from the [Inside Airbnb](http://insideairbnb.com/get-the-data.html) website.
#
# For the purpose of this analysis, the following files will be necessary:
#
# * `listings.csv` (Barcelona)
# * `listings.csv` (Madrid)
#
#  - *Summary information and metrics for listings in both cities (good for visualisations).*
#
# Note: The Inside Airbnb portal is frequently updated, and it's possible that the data set used in this notebook may no longer be accessible in the future, to resolve this, try to find the most up-to-date file of the two cities on the website.

# %%
# Imported libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Import dataset (Comma-separated values to DataFrame)
data_barc = pd.read_csv('http://data.insideairbnb.com/spain/catalonia/barcelona/2022-12-11/visualisations/listings.csv')
data_madr = pd.read_csv('http://data.insideairbnb.com/spain/comunidad-de-madrid/madrid/2022-12-13/visualisations/listings.csv')

#Rows and Columns
data_barc_shape = data_barc.shape
data_madr_shape = data_madr.shape
display(data_barc_shape)
display(data_madr_shape)

#Name of the columns
display(data_barc.columns)
display(data_madr.columns)

#Checking column names for unconformity
assert data_barc.columns.all() == data_madr.columns.all()
# Out:
# (15778, 18)
# (20776, 18)
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365', 'number_of_reviews_ltm', 'license'],
#       dtype='object')

# %% [markdown]
# ## Inspecting Data
#
# This process involves reviewing and examining the data to identify any issues or problems that need to be addressed before the data can be analyzed effectively. This will include:
#
# * Reviewing the structure of the data,
# * Exploring the data by looking at summary statistics,
# * Inconsistencies in the data, and
# * Assessing the quality of the data.
#
# The goal of the inspection process will be to gain an understanding of the data and identify any issues that need to be addressed.

# %% [markdown]
# **Data Dictionary for listings.csv detailed file**
#
# * `id` - Airbnb's unique identifier for the listing
# * `name` - Name of the listing
# * `host_id` - Airbnb's unique identifier for the host/user
# * `host_name` - Name of the host. Usually just the first name(s).
# * `neighbourhood_group` - empty.
# * `neighbourhood` - neighbourhood
# * `latitude` - Uses the World Geodetic System (WGS84) projection for latitude and longitude.
# * `longitude` - Uses the World Geodetic System (WGS84) projection for latitude and longitude.
# * `room_type` - Entire place, Private room, and Shared room.
# * `price` - daily price in local currency
# * `minimum_nights` - minimum number of night stay for the listing (calendar rules may be different)
# * `number_of_reviews` - The number of reviews the listing has
# * `last_review` - The date of the last/newest review
# * `reviews_per_month` - The number of reviews the listing has over the lifetime of the listing
# * `calculated_host_listings_count` - The number of listings the host has in the current scrape, in the city/region geography.
# * `availability_365` - avaliability_x. The availability of the listing x days in the future as determined by the calendar. Note a listing may not be available because it has been booked by a guest or blocked by the host.
# * `number_of_reviews_ltm` - The number of reviews the listing has (in the last 12 months)
# * `license` - The licence/permit/registration number
#
# Let's see the structure of the DataFrame, such as the number of columns and rows, the data types, and the presence of missing or null values.

# %%
# displaying the 5 first entries
display(data_barc.head())
# Out:
#       id                                             name  host_id  \
# 0  18674  Huge flat for 8 people close to Sagrada Familia    71615
# 1  23197  Forum CCIB DeLuxe, Spacious, Elegant ,Christmas    90417
# 2  32711                 Sagrada Familia area - Còrsega 1   135703
# 3  34981             VIDRE HOME PLAZA REAL on LAS RAMBLAS    73163
# 4  36763                            In front of the beach   158596
#
#           host_name neighbourhood_group                       neighbourhood  \
# 0  Mireia And Maria            Eixample                  la Sagrada Família
# 1    Etain (Marnie)          Sant Martí               el Besòs i el Maresme
# 2              Nick              Gràcia  el Camp d'en Grassot i Gràcia Nova
# 3            Andres        Ciutat Vella                      el Barri Gòtic
# 4             Ester        Ciutat Vella                      la Barceloneta
#
#    latitude  longitude        room_type  price  minimum_nights  \
# ...

# %%
# displaying the 5 first entries
display(data_madr.head())
# Out:
#       id                                      name    host_id host_name  \
# 0   6369  Rooftop terrace room ,  ensuite bathroom      13660     Simon
# 1  21853                      Bright and airy room      83531     Abdel
# 2  24805                    Gran Via Studio Madrid  346366726    Alvaro
# 3  26825        Single Room whith private Bathroom     114340  Agustina
# 4  37921                  Piso barrio de salamanca     162926    Sergio
#
#   neighbourhood_group   neighbourhood  latitude  longitude        room_type  \
# 0           Chamartín  Hispanoamérica  40.45724   -3.67688     Private room
# 1              Latina        Cármenes  40.40381   -3.74130     Private room
# 2              Centro     Universidad  40.42183   -3.70529  Entire home/apt
# 3          Arganzuela         Legazpi  40.38975   -3.69018     Private room
# 4           Salamanca       Recoletos  40.42325   -3.68281     Private room
#
# ...

# %% [markdown]
# The tables from Barcelona and Madrid have been successfully imported. The data organization is deemed to be of a high standard. The next step in the analysis will involve conducting a deeper examination of the data structure to uncover meaningful insights.

# %% [markdown]
# ### **Q1. How many attributes (variables) and how many entries does our dataset have? What are the types of the variables?**

# %%
#Types of the DataFrame's data:
display(data_barc.dtypes)
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object

# %%
#Types of the DataFrame's data:
display(data_madr.dtypes)
display(data_barc.columns)
# comparing the name and the types of the columns of the Madrid`s and Barcelona`s tables
assert data_barc.columns.all() == data_madr.columns.all()
for i in range(len(data_barc.columns)):
  assert data_barc.dtypes[i] == data_madr.dtypes[i]
# Out:
# id                                  int64
# name                               object
# host_id                             int64
# host_name                          object
# neighbourhood_group                object
# neighbourhood                      object
# latitude                          float64
# longitude                         float64
# room_type                          object
# price                               int64
# minimum_nights                      int64
# number_of_reviews                   int64
# last_review                        object
# reviews_per_month                 float64
# calculated_host_listings_count      int64
# availability_365                    int64
# number_of_reviews_ltm               int64
# license                            object
# dtype: object
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
# ...

# %%
# Distribution of de values of the DataFrame's data:
display(data_barc.iloc[:,8:].describe())
display(data_madr.iloc[:,8:].describe())
# Out:
#               price  minimum_nights  number_of_reviews  reviews_per_month  \
# count  15778.000000    15778.000000       15778.000000       12501.000000
# mean     140.236278       13.773672          42.448599           1.366411
# std     1021.107218       32.348957          80.548215           1.783199
# min        0.000000        1.000000           0.000000           0.010000
# 25%       45.000000        1.000000           1.000000           0.230000
# 50%       80.000000        3.000000           8.000000           0.820000
# 75%      127.000000       31.000000          45.000000           2.000000
# max    90000.000000     1125.000000        1476.000000          48.320000
#
#        calculated_host_listings_count  availability_365  number_of_reviews_ltm
# count                    15778.000000      15778.000000           15778.000000
# mean                        21.771961        184.979655              12.081062
# ...

# %%
# Determining the size of the DataFrame's data:
display(data_barc.info())
display(data_madr.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15778 entries, 0 to 15777
# Data columns (total 18 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              15778 non-null  int64
#  1   name                            15769 non-null  object
#  2   host_id                         15778 non-null  int64
#  3   host_name                       15776 non-null  object
#  4   neighbourhood_group             15778 non-null  object
#  5   neighbourhood                   15778 non-null  object
#  6   latitude                        15778 non-null  float64
#  7   longitude                       15778 non-null  float64
#  8   room_type                       15778 non-null  object
#  9   price                           15778 non-null  int64
#  10  minimum_nights                  15778 non-null  int64
#  11  number_of_reviews               15778 non-null  int64
# ...

# %% [markdown]
# It is noted that the columns in both tables have similar variables and have identical column names. The Barcelona table has 15,778 entries, while the Madrid table has 20,776 entries. The data distributions are presented, and it is observed that the `price` are fairly similar in nature. However, a distinction is seen in the distribution of `minimum_nights`, with Barcelona having a interesting distribution pattern. During the next session, the examination of the data will take place in order to determine the presence of any missing values. Additionally, the identification of which columns contain these missing entries will be conducted.

# %% [markdown]
# ### **Q2. What percentage of values are missing from the *dataset*?**

# %%
# sort in descending order the variables by their missing values
display((data_barc.isnull().sum().sort_values(ascending=False) / data_barc_shape[0])*100)
# Out:
# license                           31.524908
# reviews_per_month                 20.769426
# last_review                       20.769426
# name                               0.057041
# host_name                          0.012676
# minimum_nights                     0.000000
# number_of_reviews_ltm              0.000000
# availability_365                   0.000000
# calculated_host_listings_count     0.000000
# number_of_reviews                  0.000000
# id                                 0.000000
# room_type                          0.000000
# longitude                          0.000000
# latitude                           0.000000
# neighbourhood                      0.000000
# neighbourhood_group                0.000000
# host_id                            0.000000
# price                              0.000000
# dtype: float64

# %%
# sort in descending order the variables by their missing values
display((data_madr.isnull().sum().sort_values(ascending=False) / data_madr_shape[0])*100)
# Out:
# license                           86.821332
# reviews_per_month                 19.864266
# last_review                       19.864266
# name                               0.019253
# host_name                          0.014440
# minimum_nights                     0.000000
# number_of_reviews_ltm              0.000000
# availability_365                   0.000000
# calculated_host_listings_count     0.000000
# number_of_reviews                  0.000000
# id                                 0.000000
# room_type                          0.000000
# longitude                          0.000000
# latitude                           0.000000
# neighbourhood                      0.000000
# neighbourhood_group                0.000000
# host_id                            0.000000
# price                              0.000000
# dtype: float64

# %% [markdown]
# As can be observed, the same four columns contain missing data: `license`, `reviews_per_month`, `last_review`, `name`, and `host_name`. The first column `license` suggests that obtaining the necessary permission to operate a guest accommodation business in Spain may not be a straightforward process, or it may not even be required, depending on the type of accommodation. The number of `reviews_per_month` appears to be in proportion with the missing `last_review`, which could raise a point if these variables are related, and if some types of accommodations tend to have less reviews. Furthermore, there is also a low proportion of missing names for both listings and hosts. In the next section, the distributions of these variables will be plotted and an analysis of the relationship between these variables and the different types of housing will be conducted.

# %% [markdown]
# ### **Q3. What is the type of distribution of the variables?**

# %%
# Plot of the Plot empirical cumulative distribution functions for Barcelona`s price and minimim_nights
sns.set(rc={'figure.figsize':(8,6)})
f, axes = plt.subplots(1, 2)
ax = sns.ecdfplot(data=data_barc, x='price', ax=axes[0])
ax2 = sns.ecdfplot(data=data_barc, x='minimum_nights', ax=axes[1])

# %%
# Plot of the Plot empirical cumulative distribution functions for Madrid`s price and minimim_nights
f, axes = plt.subplots(1, 2)
ax = sns.ecdfplot(data=data_madr, x='price', ax=axes[0])
ax2 = sns.ecdfplot(data=data_madr, x='minimum_nights', ax=axes[1])

# %%
# Copying the DataFrame to prevent any modifications to the original data.
data_barc_2 = data_barc.copy()
data_madr_2 = data_madr.copy()

# New column 'city'
data_barc_2['city'] = 'Barcelona'
data_madr_2['city'] = 'Madrid'

# Appending both dataframes
df = data_barc_2.append(data_madr_2, ignore_index=True)

# Slicing the desired variables
df = df[(df['minimum_nights'] <= 32) & (df['price'] <= 350)]

# Amount of discarded data:
display((df[df['city']=='Barcelona'].shape[0]/data_barc_shape[0])*100)
display((df[df['city']=='Madrid'].shape[0]/data_madr_shape[0])*100)
# Out:
# 94.41627582710103
# 93.01116673084327

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.ecdfplot(data=df, x='price', hue="city")

# %%
sns.set(rc={'figure.figsize':(8,6)})
sns.ecdfplot(data=df, x='minimum_nights', hue="city")

# %%
# plot the boxplot of numeric variables price by room type and city
sns.set(rc={'figure.figsize':(8,6)})
sns.boxplot(data=df, x='price', y='room_type', hue="city")

# %%
# plot the boxplot of numeric variables minimum nights by room type and city
sns.boxplot(data=df, x='minimum_nights', y='room_type', hue="city")

# %%
# plot the boxplot of numeric variables total number of reviews by room type and city
sns.boxplot(data=df, x='number_of_reviews', y='room_type', hue="city")

# %%
# plot the boxplot of numeric variables reviews/month by room type and city
sns.boxplot(data=df, x='reviews_per_month', y='room_type', hue="city")

# %%
# plot the boxplot of numeric variables host listings count by room type and city
sns.boxplot(data=df, x='calculated_host_listings_count', y='room_type', hue="city")

# %%
# plot the boxplot of numeric variables availability in 365 days by room type and city
sns.boxplot(data=df, x='availability_365', y='room_type', hue="city")

# %%
# plot the boxplot of numeric variables number of reviews last 12 months by room type and city
sns.boxplot(data=df, x='number_of_reviews_ltm', y='room_type', hue="city")

# %%
# calculate the annual earnings for a rental apartment

df['annual_earnings'] = (365 - df['availability_365'])*df['price']

# plot the boxplot of annual_earnings by room type and city
sns.boxplot(data=df, x='annual_earnings', y='room_type', hue="city")

# %% [markdown]
# Important insights have been drawn from the analysis. The distribution of rental prices for apartments and hotels is similar, while the cost of renting a room is typically half of those values. When guests seek to save money, they can opt for shared rooms, which offer low costs. In terms of minimum nights, housing in the city of Barcelona typically requires longer stays for guests who are renting apartments or private rooms. The availability of housing for all 365 days is a significant factor in the analysis. Apartments tend to have higher vacancy rates in Barcelona, while private rooms are in high demand during this period. In Madrid, the distribution of apartments and hotels is very similar.

# %% [markdown]
# ### **Q4. What is the average rental price?**

# %%
# See column 'price' average
price_madr_mean = df[df['city']=='Madrid'].price.mean()
price_barc_mean = df[df['city']=='Barcelona'].price.mean()

print("Madrid's average rental price:" + str(price_madr_mean) + ', and \n' + "Barcelona's average rental price:" + str(price_barc_mean))
# Out:
# Madrid's average rental price:93.61239908921549, and
# Barcelona's average rental price:93.04390145666913

# %% [markdown]
# As can be observed, on average, rental values in both cities are higher.

# %% [markdown]
# ### **Q4. What is the correlation between the variables**

# %%
# Creating a column for each type of the variable 'room_type'

for type in df['room_type'].unique():
  df[type] = 0
  for i in range(df.shape[0]):
    if df['room_type'].iloc[i] == type:
      df[type].iloc[i] = 1

# %%
# Creating a column for the service license

df['licensed'] = df['license'].notnull().astype('int')

# %%
# create a correlation matrix
corr_Madr = df[df['city']=='Madrid'][['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count',
                 'availability_365', 'number_of_reviews_ltm', 'licensed', 'Entire home/apt', 'Private room', 'Hotel room', 'Shared room']].corr()
corr_Barc = df[df['city']=='Barcelona'][['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count', 
                 'availability_365', 'number_of_reviews_ltm', 'licensed', 'Entire home/apt', 'Private room', 'Hotel room', 'Shared room']].corr()
#corr = df[['latitude', 'longitude', 'price', 'minimum_nights', 'number_of_reviews', 'reviews_per_month', 'calculated_host_listings_count',
#                 'availability_365', 'number_of_reviews_ltm', 'Entire home/apt', 'Private room', 'Hotel room', 'Shared room']].corr()
# show the correlation matrix
display(corr_Madr)
display(corr_Barc)
# Out:
#                                 latitude  longitude     price  minimum_nights  \
# latitude                        1.000000   0.260665  0.054689        0.060672
# longitude                       0.260665   1.000000 -0.038730       -0.012625
# price                           0.054689  -0.038730  1.000000       -0.025486
# minimum_nights                  0.060672  -0.012625 -0.025486        1.000000
# number_of_reviews              -0.048113  -0.039103 -0.011265       -0.132686
# reviews_per_month              -0.036990   0.008730 -0.019680       -0.198130
# calculated_host_listings_count  0.017380  -0.033144  0.161835        0.250729
# availability_365                0.004698   0.005102  0.196780        0.021257
# number_of_reviews_ltm          -0.044892  -0.026250  0.008581       -0.190338
# licensed                       -0.019549  -0.040672  0.187616       -0.066219
# Entire home/apt                 0.031208  -0.074051  0.455793        0.100371
# ...

# %%
# plot a heatmap from the correlations
sns.set(rc={'figure.figsize':(12,10)})
sns.heatmap(corr_Madr, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True)

# %%
# plot a heatmap from the correlations
sns.heatmap(corr_Barc, cmap='RdBu', fmt='.2f', square=True, linecolor='white', annot=True)

# %% [markdown]
# Several notable points have been identified, including a correlation between the rental prices for apartments and private rooms in both cities. In the case of Barcelona, the relationship between availability in the last 365 days for rooms and apartments, possession of service licenses, and price is particularly striking.

# %% [markdown]
# ### **Q5. What type of property is most rented on Airbnb?**

# %%
# Quantity and Percentage of each type of property available for Madrid
madr_by_type = df[df['city']=='Madrid']['room_type'].value_counts()
display(madr_by_type)
print('___________________________________')
display((madr_by_type/ df[df['city']=='Madrid'].shape[0])*100)
# Out:
# Entire home/apt    12356
# Private room        6587
# Shared room          260
# Hotel room           121
# Name: room_type, dtype: int64
# ___________________________________
# Entire home/apt    63.941213
# Private room       34.087146
# Shared room         1.345477
# Hotel room          0.626164
# Name: room_type, dtype: float64

# %%
# Quantity and Percentage of each type of property available for Barcelona
barc_by_type = df[df['city']=='Barcelona']['room_type'].value_counts()
display(barc_by_type)
print('___________________________________')
display((barc_by_type/ df[df['city']=='Barcelona'].shape[0])*100)
# Out:
# Entire home/apt    8806
# Private room       5773
# Hotel room          160
# Shared room         158
# Name: room_type, dtype: int64
# ___________________________________
# Entire home/apt    59.112573
# Private room       38.752769
# Hotel room          1.074042
# Shared room         1.060616
# Name: room_type, dtype: float64

# %% [markdown]
# It can be seen here that in Madrid, there is a higher availability for renting apartments, whereas in Barcelona, there is a greater supply of private rooms.

# %% [markdown]
# ### **Q6. Where is the highly attractive neighborhood in the dataset?**

# %%
#Creating a new dataset
data_barc_NG = data_barc.set_index('neighbourhood_group').sort_index()
data_barc_NG= data_barc_NG[(data_barc_NG['minimum_nights'] <= 32) & (data_barc_NG['price'] <= 350)]
data_madr_NG = data_madr.set_index('neighbourhood_group').sort_index()
data_madr_NG= data_madr_NG[(data_madr_NG['minimum_nights'] <= 32) & (data_madr_NG['price'] <= 350)]

# %%
# number of properties by neighborhood
sns.set(rc={'figure.figsize':(8,6)})
f, axes = plt.subplots(1, 2)
ax = sns.countplot(x=data_barc_NG.index, data=data_barc_NG, ax=axes[0])
ax2 = sns.countplot(x=data_madr_NG.index, data=data_madr_NG, ax=axes[1])
ax.tick_params(axis='x', rotation=90)
ax2.tick_params(axis='x', rotation=90)

# %%
# see average prices by neighbourhood_group
f, axes = plt.subplots(1, 2)
ax = sns.barplot(x = data_barc_NG.index, y=data_barc_NG.price, ax=axes[0])
ax.tick_params(axis='x', rotation=90)
ax2 = sns.barplot(x = data_madr_NG.index, y = data_madr_NG.price, ax=axes[1])
ax2.tick_params(axis='x', rotation=90)

# %%
# Availability of properties by neighborhood
f, axes = plt.subplots(1, 2)
ax = sns.barplot(x=data_barc_NG.index, y = "availability_365", data=data_barc_NG, ax=axes[0])
ax2 = sns.barplot(x=data_madr_NG.index, y = "availability_365", data=data_madr_NG, ax=axes[1])
ax.tick_params(axis='x', rotation=90)
ax2.tick_params(axis='x', rotation=90)

# %%
# plot properties by latitude-longitude
sns.set(rc={'figure.figsize':(20,8)})
f, axes = plt.subplots(1, 2)
#ax = sns.scatterplot(data=df[df['city']=='Barcelona'], x='longitude', y='latitude', hue='neighbourhood_group', ax=axes[0])
ax = sns.scatterplot(data=data_barc_NG, x='longitude', y='latitude', hue=data_barc_NG.index, size = 'price', sizes=(0.1, 5),ax=axes[0])
ax.plot([2.165],[41.3925],'o',ms=100,mec='r', mew = 2,mfc='none')
#ax2 = sns.scatterplot(data=df[df['city']=='Madrid'], x='longitude', y='latitude', hue='neighbourhood_group', ax=axes[1])
ax2 = sns.scatterplot(data=data_madr_NG, x='longitude', y='latitude', hue=data_madr_NG.index, size = 'price', sizes=(0.1, 5),ax=axes[1])
ax2.plot([-3.70],[40.42],'o',ms=100,mec='b', mew = 2,mfc='none')

# %% [markdown]
# As can be seen, the neighborhood `Centro` in Madrid appears to be a highly relevant area for further research and consideration for real estate investment. This neighborhood offers a high level of availability and is located close to popular tourist areas. Additionally, rental prices in this area are relatively higher compared to other neighborhoods, and availability remains consistent throughout the year, with only minimal fluctuations.
#
# In Barcelona, the neighborhoods of `Eixample`, `Gràcia`, and `Ciutat Vella` are highly attractive due to their proximity to tourist attractions, as well as they are near to world-renowned art schools. This recognition and popularity has resulted in high rental values and high demand, as indicated by the low availability in 365 days.

# %% [markdown]
# ### **Q7. What is the average minimum rental nights (minimum_nights)?**

# %%
#Creating a new dataset
data_barc_MN= data_barc[(data_barc['minimum_nights'] <= 32) & (data_barc['price'] <= 130)]
data_barc_MN = data_barc_MN.set_index('minimum_nights').sort_index()
data_madr_MN= data_madr[(data_madr['minimum_nights'] <= 32) & (data_madr['price'] <= 130)]
data_madr_MN = data_madr_MN.set_index('minimum_nights').sort_index()

# %%
# Price by minimum nights
sns.set(rc={'figure.figsize':(8,6)})
f, axes = plt.subplots(1, 2)
ax = sns.barplot(x = data_barc_MN.index, y=data_barc_MN.price, ax=axes[0])
ax.tick_params(axis='x', rotation=90)
ax2 = sns.barplot(x = data_madr_MN.index, y = data_madr_MN.price, ax=axes[1])
ax2.tick_params(axis='x', rotation=90)

# %%
# see the average of the `minimum_nights` column for Barcelona
r = [0, 0]
list_of_mean = pd.Series(r)
for i in data_barc_MN.index.unique():
  list_of_mean[i] = data_barc_MN['price'].loc[i].mean()
print(list_of_mean.sort_values(ascending=False).head())
# Out:
# 27    100.000000
# 29     87.600000
# 3      77.781130
# 4      77.546667
# 14     75.750000
# dtype: float64

# %%
#see the average of the `minimum_nights` column for Madrid
r = [0, 0]
list_of_mean = pd.Series(r)
for i in data_madr_MN.index.unique():
  list_of_mean[i] = data_madr_MN['price'].loc[i].mean()
print(list_of_mean.sort_values(ascending=False).head())
# Out:
# 31    92.433333
# 27    82.789474
# 32    77.195652
# 4     74.332366
# 3     74.133994
# dtype: float64

# %% [markdown]
# This final session reveals a noteworthy factor for both cities, which is that on average, Barcelona has higher prices for 1-month rental periods.

# %% [markdown]
# ## Findings

# %% [markdown]
# <center><img alt="Colaboratory logo" width="15%" src="https://raw.githubusercontent.com/carlosfab/escola-data-science/master/img/novo_logo_bg_claro.png">
#
# #### **Data Science na Prática 3.0**
#
# *by [sigmoidal.ai](https://sigmoidal.ai)*
#
# ---
# ***Pedro Bernardo dos Santos Melo***</center>
# ## Which city, Barcelona or Madrid, would be the most profitable location to invest in?
#
# <center><img alt="Analisando Airbnb" width="10%" src="https://www.area360.com.au/wp-content/uploads/2017/09/airbnb-logo.jpg"></center>
#
# The well-organized and captivating database allowed me to perform a research on which Spanish city would be ideal for someone looking to invest in real estate.
#
# For instance, Barcelona could be a great place to rent a room for an art or architecture student, while Madrid could be a great option for travelers.
# I selected Barcelona for its long-standing appeal to artists and architects from all over the world due to its cultural richness and architectural heritage.
# One of the key factors contributing to this appeal is Antoni Gaudi's iconic works like Park Güell, Casa Batlló, and the Sagrada Familia. Gaudi's imaginative and unparalleled approach to architecture, along with his integration of nature and organic forms, has made him a renowned architect globally. Moreover, Barcelona's rich historical and cultural background further adds to its charm. The Gothic Quarter, with its medieval buildings and narrow streets, is a vivid example of the city's cultural richness.
# Additionally, Barcelona boasts a thriving art scene, which attracts artists and architects in search of creative inspiration and opportunities. The Joan Miro Foundation, the Picasso Museum, and the contemporary art museum MACBA are just a few examples of the cultural institutions present in the city.
# In conclusion, Barcelona's rich cultural and architectural heritage and its thriving art scene make it a desirable destination for artists and architects worldwide.
#
# The opportunity to apply my skills gained from the Sigmoidal.ai course and incorporate this analysis into my portfolio made this an exciting experience. Thank you.
